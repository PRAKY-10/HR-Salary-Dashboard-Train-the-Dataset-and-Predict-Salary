# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Data = pd.read_csv(r'D:\TCS Project\Data\Data.csv')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337884 entries, 0 to 337883
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Fiscal Year                 337884 non-null  int64
#  1   Payroll Number              337884 non-null  float64
#  2   Agency Name                 337884 non-null  object
#  3   Last Name                   332219 non-null  object
#  4   First Name                  332215 non-null  object
#  5   Mid Init                    202360 non-null  object
#  6   Age                         337884 non-null  int64
#  7   Joined Date                 337884 non-null  object
#  8   Work Location Borough       337883 non-null  object
#  9   Job Description             337881 non-null  object
#  10  Leave Status as of June 30  337884 non-null  object
#  11  Base Salary                 337884 non-null  float64
#  12  Pay Basis                   337884 non-null  object
# ...

# %%
Data.head()
# Out:
#    Fiscal Year  Payroll Number                Agency Name      Last Name  \
# 0         2022            67.0  ADMIN FOR CHILDREN'S SVCS  PERRY SPENCER
# 1         2022            67.0  ADMIN FOR CHILDREN'S SVCS         BIEBER
# 2         2022            67.0  ADMIN FOR CHILDREN'S SVCS           BIER
# 3         2022            67.0  ADMIN FOR CHILDREN'S SVCS          BILAK
# 4         2022            67.0  ADMIN FOR CHILDREN'S SVCS         BILLAH
#
#   First Name Mid Init  Age Joined Date Work Location Borough  \
# 0       VARA      NaN   36  2021-05-24                QUEENS
# 1     STEVEN      NaN   59  1996-06-23             MANHATTAN
# 2    RICHARD        M   60  1996-06-23             MANHATTAN
# 3      DONNA      NaN   56  2000-06-26             MANHATTAN
# 4       KAZI        S   45  2001-07-09             MANHATTAN
#
#                                    Job Description Leave Status as of June 30  \
# ...

# %% [markdown]
# # Cleaning and Sanitizing

# %%
sum(Data['First Name'].isnull() & Data['Last Name'].isnull())
# Out:
# 5664

# %%
sum(Data['Last Name'].isnull())
# Out:
# 5665

# %%
Data.dropna(subset=['First Name', 'Last Name'], thresh = 1, inplace = True)

# %%
Data[Data['First Name'].isnull()]
# Out:
#         Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 14786          2022           469.0   COMMUNITY COLLEGE (LAGUARDIA)        XU
# 94750          2022           744.0   DEPT OF ED PARA PROFESSIONALS        SU
# 209999         2022           826.0  DEPT OF ENVIRONMENT PROTECTION       KIM
# 215414         2022           816.0   DEPT OF HEALTH/MENTAL HYGIENE        LI
# 220736         2022           858.0    DEPT OF INFO TECH & TELECOMM      CHEN
#
#        First Name Mid Init  Age Joined Date Work Location Borough  \
# 14786         NaN      NaN   40  2014-09-01                QUEENS
# 94750         NaN      NaN   26  2020-02-27             MANHATTAN
# 209999        NaN        R   29  2015-02-23                QUEENS
# 215414        NaN      NaN   37  2017-01-30                QUEENS
# 220736        NaN      NaN   34  2019-11-18             MANHATTAN
#
#               Job Description Leave Status as of June 30  Base Salary  \
# ...

# %%
Data[Data['Last Name'].isnull()]
# Out:
#         Fiscal Year  Payroll Number                    Agency Name Last Name  \
# 214682         2022           816.0  DEPT OF HEALTH/MENTAL HYGIENE       NaN
#
#        First Name Mid Init  Age Joined Date Work Location Borough  \
# 214682     YUNJIN      NaN   46  2008-10-20                QUEENS
#
#        Job Description Leave Status as of June 30  Base Salary  Pay Basis
# 214682      ACCOUNTANT                     ACTIVE      89599.0  per Annum

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332220 entries, 0 to 337883
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Fiscal Year                 332220 non-null  int64
#  1   Payroll Number              332220 non-null  float64
#  2   Agency Name                 332220 non-null  object
#  3   Last Name                   332219 non-null  object
#  4   First Name                  332215 non-null  object
#  5   Mid Init                    202354 non-null  object
#  6   Age                         332220 non-null  int64
#  7   Joined Date                 332220 non-null  object
#  8   Work Location Borough       332219 non-null  object
#  9   Job Description             332217 non-null  object
#  10  Leave Status as of June 30  332220 non-null  object
#  11  Base Salary                 332220 non-null  float64
#  12  Pay Basis                   332220 non-null  object
# ...

# %%
Data['Name'] = Data['First Name']+' '+Data['Last Name']

# %%
Data.head()
# Out:
#    Fiscal Year  Payroll Number                Agency Name      Last Name  \
# 0         2022            67.0  ADMIN FOR CHILDREN'S SVCS  PERRY SPENCER
# 1         2022            67.0  ADMIN FOR CHILDREN'S SVCS         BIEBER
# 2         2022            67.0  ADMIN FOR CHILDREN'S SVCS           BIER
# 3         2022            67.0  ADMIN FOR CHILDREN'S SVCS          BILAK
# 4         2022            67.0  ADMIN FOR CHILDREN'S SVCS         BILLAH
#
#   First Name Mid Init  Age Joined Date Work Location Borough  \
# 0       VARA      NaN   36  2021-05-24                QUEENS
# 1     STEVEN      NaN   59  1996-06-23             MANHATTAN
# 2    RICHARD        M   60  1996-06-23             MANHATTAN
# 3      DONNA      NaN   56  2000-06-26             MANHATTAN
# 4       KAZI        S   45  2001-07-09             MANHATTAN
#
#                                    Job Description Leave Status as of June 30  \
# ...

# %% [markdown]
# # Removing unnecessary columns

# %%
Data.drop(columns = ['First Name', 'Last Name', 'Mid Init'], inplace = True)

# %%
Data.drop(columns = ['Fiscal Year', 'Payroll Number', 'Pay Basis', 'Leave Status as of June 30'], inplace = True)

# %%
Data.head()
# Out:
#                  Agency Name  Age Joined Date Work Location Borough  \
# 0  ADMIN FOR CHILDREN'S SVCS   36  2021-05-24                QUEENS
# 1  ADMIN FOR CHILDREN'S SVCS   59  1996-06-23             MANHATTAN
# 2  ADMIN FOR CHILDREN'S SVCS   60  1996-06-23             MANHATTAN
# 3  ADMIN FOR CHILDREN'S SVCS   56  2000-06-26             MANHATTAN
# 4  ADMIN FOR CHILDREN'S SVCS   45  2001-07-09             MANHATTAN
#
#                                    Job Description  Base Salary  \
# 0                      CHILD PROTECTIVE SPECIALIST      55125.0
# 1       ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES     117748.0
# 2                     ADMINISTRATIVE STAFF ANALYST      93534.0
# 3  PRINCIPAL ADMINISTRATIVE ASSOCIATE -  NON SUPVR      67600.0
# 4                            COMMUNITY COORDINATOR      81246.0
#
#                  Name
# 0  VARA PERRY SPENCER
# 1       STEVEN BIEBER
# 2        RICHARD BIER
# 3         DONNA BILAK
# 4         KAZI BILLAH

# %%
Data = Data[['Agency Name', 'Name', 'Age', 'Joined Date', 'Work Location Borough', 'Job Description', 'Base Salary']]

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age Joined Date  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36  2021-05-24
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59  1996-06-23
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60  1996-06-23
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56  2000-06-26
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45  2001-07-09
#
#   Work Location Borough                                  Job Description  \
# 0                QUEENS                      CHILD PROTECTIVE SPECIALIST
# 1             MANHATTAN       ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES
# 2             MANHATTAN                     ADMINISTRATIVE STAFF ANALYST
# 3             MANHATTAN  PRINCIPAL ADMINISTRATIVE ASSOCIATE -  NON SUPVR
# 4             MANHATTAN                            COMMUNITY COORDINATOR
#
#    Base Salary
# 0      55125.0
# 1     117748.0
# 2      93534.0
# 3      67600.0
# 4      81246.0

# %% [markdown]
# # Renaming the columns

# %%
Data.rename(columns = {'Work Location Borough':'Work Location', 'Job Description':'Job', 'Base Salary':'Salary'}, inplace = True)

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age Joined Date  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36  2021-05-24
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59  1996-06-23
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60  1996-06-23
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56  2000-06-26
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45  2001-07-09
#
#   Work Location                                              Job    Salary
# 0        QUEENS                      CHILD PROTECTIVE SPECIALIST   55125.0
# 1     MANHATTAN       ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES  117748.0
# 2     MANHATTAN                     ADMINISTRATIVE STAFF ANALYST   93534.0
# 3     MANHATTAN  PRINCIPAL ADMINISTRATIVE ASSOCIATE -  NON SUPVR   67600.0
# 4     MANHATTAN                            COMMUNITY COORDINATOR   81246.0

# %%
Data['Joined Date'] = pd.to_datetime(Data['Joined Date'])

# %%
Data['Joined Year'] = Data['Joined Date'].dt.year

# %%
Data['Years of experience'] = 2022 - Data['Joined Year']

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age Joined Date  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36  2021-05-24
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59  1996-06-23
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60  1996-06-23
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56  2000-06-26
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45  2001-07-09
#
#   Work Location                                              Job    Salary  \
# 0        QUEENS                      CHILD PROTECTIVE SPECIALIST   55125.0
# 1     MANHATTAN       ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES  117748.0
# 2     MANHATTAN                     ADMINISTRATIVE STAFF ANALYST   93534.0
# 3     MANHATTAN  PRINCIPAL ADMINISTRATIVE ASSOCIATE -  NON SUPVR   67600.0
# 4     MANHATTAN                            COMMUNITY COORDINATOR   81246.0
#
#    Joined Year  Years of experience
# 0         2021                    1
# 1         1996                   26
# ...

# %%
Data.drop(columns = ['Joined Date', 'Joined Year'], inplace = True)

# %%
Data = Data[['Agency Name', 'Name', 'Age', 'Years of experience', 'Work Location', 'Job', 'Salary']]

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age  Years of experience  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36                    1
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59                   26
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60                   26
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56                   22
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45                   21
#
#   Work Location                                              Job    Salary
# 0        QUEENS                      CHILD PROTECTIVE SPECIALIST   55125.0
# 1     MANHATTAN       ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES  117748.0
# 2     MANHATTAN                     ADMINISTRATIVE STAFF ANALYST   93534.0
# 3     MANHATTAN  PRINCIPAL ADMINISTRATIVE ASSOCIATE -  NON SUPVR   67600.0
# 4     MANHATTAN                            COMMUNITY COORDINATOR   81246.0

# %%
Data['Salary'] = Data['Salary'].astype(int)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332220 entries, 0 to 337883
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Agency Name          332220 non-null  object
#  1   Name                 332214 non-null  object
#  2   Age                  332220 non-null  int64
#  3   Years of experience  332220 non-null  int64
#  4   Work Location        332219 non-null  object
#  5   Job                  332217 non-null  object
#  6   Salary               332220 non-null  int32
# dtypes: int32(1), int64(2), object(4)
# memory usage: 19.0+ MB

# %% [markdown]
# # Removing null values

# %%
Data.dropna(inplace = True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332210 entries, 0 to 337883
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Agency Name          332210 non-null  object
#  1   Name                 332210 non-null  object
#  2   Age                  332210 non-null  int64
#  3   Years of experience  332210 non-null  int64
#  4   Work Location        332210 non-null  object
#  5   Job                  332210 non-null  object
#  6   Salary               332210 non-null  int32
# dtypes: int32(1), int64(2), object(4)
# memory usage: 19.0+ MB

# %% [markdown]
# # Removing duplicate rows

# %%
Data.drop_duplicates(subset = ['Agency Name','Name','Age','Years of experience','Work Location','Job','Salary'],keep = 'last',inplace = True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332203 entries, 0 to 337883
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Agency Name          332203 non-null  object
#  1   Name                 332203 non-null  object
#  2   Age                  332203 non-null  int64
#  3   Years of experience  332203 non-null  int64
#  4   Work Location        332203 non-null  object
#  5   Job                  332203 non-null  object
#  6   Salary               332203 non-null  int32
# dtypes: int32(1), int64(2), object(4)
# memory usage: 19.0+ MB

# %%
Data.reset_index(inplace = True)
Data.drop(columns='index', inplace = True)

# %%
Data
# Out:
#                        Agency Name                Name  Age  \
# 0        ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36
# 1        ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59
# 2        ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60
# 3        ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56
# 4        ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45
# ...                            ...                 ...  ...
# 332198  TEACHERS RETIREMENT SYSTEM     AZALEA ANDERSON   37
# 332199  TEACHERS RETIREMENT SYSTEM      MIKHAIL AMINOV   37
# 332200  TEACHERS RETIREMENT SYSTEM     SUZANNE ALLEYNE   43
# 332201  TEACHERS RETIREMENT SYSTEM           ROSNA ALI   27
# 332202  TEACHERS RETIREMENT SYSTEM   ARISTEA AFTOUSMIS   50
#
#         Years of experience Work Location  \
# 0                         1        QUEENS
# 1                        26     MANHATTAN
# 2                        26     MANHATTAN
# 3                        22     MANHATTAN
# ...

# %% [markdown]
# # Descriptive analysis

# %%
print('No. of rows: ',Data.shape[0])
print('No. of columns: ',Data.shape[1])
# Out:
# No. of rows:  332203
# No. of columns:  7

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(Data,explorative = True)
profile.to_file(output_file='EDA.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-05-11 10:54:02.846297&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
print('No. of Work Locations: ',len(Data['Work Location'].unique()))
print('\n')
print('No. of employees in each Work Location:\n',pd.value_counts(Data['Work Location']))
# Out:
# No. of Work Locations:  18
#
#
# No. of employees in each Work Location:
#  MANHATTAN        214945
# QUEENS            46255
# BROOKLYN          39878
# BRONX             21456
# RICHMOND           5715
# OTHER              2873
# WESTCHESTER         460
# ULSTER              300
# SULLIVAN            113
# DELAWARE             76
# PUTNAM               37
# SCHOHARIE            28
# NASSAU               19
# DUTCHESS             19
# ALBANY               13
# GREENE                9
# WASHINGTON DC         6
# ORANGE                1
# Name: Work Location, dtype: int64

# %%
print('No. of Jobs: ',len(Data['Job'].unique()))
print('\n')
print('No. of employees in each Job:\n',pd.value_counts(Data['Job']))
# Out:
# No. of Jobs:  1287
#
#
# No. of employees in each Job:
#  TEACHER                                                     58576
# ANNUAL ED PARA                                              31382
# TEACHER SPECIAL EDUCATION                                   28933
# POLICE OFFICER                                              23550
# FIREFIGHTER                                                  9374
#                                                             ...
# DIRECTOR OF ADMINISTRATION                                      1
# ASSISTANT COMISSIONER FOR FAMILY OPERATIONS                     1
# ASST COMMISSIONER FOR PLANNING & PROGRAM DEV                    1
# HUMAN RESOURCES TECHNICIAN                                      1
# SECRETARY TO THE EXECUTIVE DIRECTOR OF RETIREMENT SYSTEM        1
# Name: Job, Length: 1287, dtype: int64

# %%
print('No. of employees with years of experience:\n',pd.value_counts(Data['Years of experience']))
# Out:
# No. of employees with years of experience:
#  6     20407
# 3     20267
# 1     19345
# 4     18371
# 7     17060
# 5     16693
# 8     15931
# 9     12497
# 15    12416
# 17    12344
# 16    12131
# 10    11115
# 18    10639
# 14    10637
# 2      9871
# 11     9311
# 21     9153
# 23     8979
# 22     8697
# 19     8267
# 24     7962
# 0      7683
# 20     7615
# 26     7576
# 12     7071
# 25     7066
# 13     4644
# 29     4301
# 27     4002
# 30     3789
# 28     3709
# 31     2654
# Name: Years of experience, dtype: int64

# %%
Data['Work Location'].unique()
# Out:
# array(['QUEENS', 'MANHATTAN', 'BRONX', 'BROOKLYN', 'RICHMOND', 'NASSAU',
#        'WESTCHESTER', 'SULLIVAN', 'ORANGE', 'DELAWARE', 'OTHER', 'ULSTER',
#        'PUTNAM', 'DUTCHESS', 'SCHOHARIE', 'GREENE', 'ALBANY',
#        'WASHINGTON DC'], dtype=object)

# %%
Data['Job'].unique()
# Out:
# array(['CHILD PROTECTIVE SPECIALIST',
#        'ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES',
#        'ADMINISTRATIVE STAFF ANALYST', ...,
#        'ASSOCIATE TAXI & LIMOUSINE INSPECTOR', 'IT PROJECT SPECIALIsT',
#        'SECRETARY TO THE EXECUTIVE DIRECTOR OF RETIREMENT SYSTEM'],
#       dtype=object)

# %%
plt.boxplot(x=Data['Age'])
plt.show()

# %%
print('Highest age: ',Data['Age'].max())
print('Lowest age: ',Data['Age'].min())
print('Mean : ',Data['Age'].mean())
print('Median : ',Data['Age'].median())
# Out:
# Highest age:  66
# Lowest age:  20
# Mean :  39.629879922818276
# Median :  39.0

# %%
plt.boxplot(x=Data['Years of experience'])
plt.show()

# %%
print('Highest years of experience: ',Data['Years of experience'].max())
print('Lowest years of experience: ',Data['Years of experience'].min())
print('Mean : ',Data['Years of experience'].mean())
print('Median : ',Data['Years of experience'].median())
# Out:
# Highest years of experience:  31
# Lowest years of experience:  0
# Mean :  12.115330084315914
# Median :  10.0

# %%
plt.figure()
plt.boxplot(x=Data['Salary'])
plt.show()

# %%
print('Highest salary: ',Data['Salary'].max())
print('Lowest salary: ',Data['Salary'].min())
print('Mean : ',Data['Salary'].mean())
print('Median : ',Data['Salary'].median())
# Out:
# Highest salary:  414707
# Lowest salary:  20158
# Mean :  79890.58864308872
# Median :  80332.0

# %%
Data[Data['Salary']>300000]
# Out:
#                       Agency Name                Name  Age  \
# 201106     DEPT OF ED PEDAGOGICAL  MEISHA ROSS PORTER   46
# 268313      NYC HOUSING AUTHORITY        GREGORY RUSS   34
# 278586      OFFICE OF THE ACTUARY         SHERRY CHAN   34
# 278614      OFFICE OF THE ACTUARY       MICHAEL SAMET   39
# 279190  OFFICE OF THE COMPTROLLER         ALEXIS DONE   45
#
#         Years of experience Work Location                         Job  Salary
# 201106                   21     MANHATTAN    ASSISTANT SUPERINTENDENT  363346
# 268313                    3     MANHATTAN                       CHAIR  414707
# 278586                    7     MANHATTAN               CHIEF ACTUARY  311885
# 278614                   11     MANHATTAN      ADMINISTRATIVE ACTUARY  311885
# 279190                   10     MANHATTAN  PENSION INVESTMENT ADVISOR  350000

# %%
Data[Data['Job']=='CHAIR']
# Out:
#                           Agency Name              Name  Age  \
# 11166   BUSINESS INTEGRITY COMMISSION  ELIZABETH CROTTY   35
# 11178   BUSINESS INTEGRITY COMMISSION        NOAH GENEL   41
# 268313          NYC HOUSING AUTHORITY      GREGORY RUSS   34
#
#         Years of experience Work Location    Job  Salary
# 11166                     0     MANHATTAN  CHAIR  243171
# 11178                     7     MANHATTAN  CHAIR  243171
# 268313                    3     MANHATTAN  CHAIR  414707

# %%
q1 = np.percentile(Data['Salary'],25)
q3 = np.percentile(Data['Salary'],75)

# %%
iqr = q3-q1

lower_bound = q1 - (iqr * 1.5)
upper_bound = q3 + (iqr * 1.5)

# %%
print('Upper bound: ',upper_bound)
print('Lower bound: ',lower_bound)
# Out:
# Upper bound:  178292.0
# Lower bound:  -26644.0

# %%
out_data = Data[(Data['Salary']>upper_bound) | (Data['Salary']<lower_bound)]

# %%
print('No. of Jobs: ',len(out_data['Job'].unique()))
print('\n')
print('No. of employees in each Job:\n',pd.value_counts(out_data['Job']))
# Out:
# No. of Jobs:  260
#
#
# No. of employees in each Job:
#  PRINCIPAL                                              989
# ASSISTANT DISTRICT ATTORNEY                            155
# CAPTAIN D/A DEPUTY INSPECTOR                           137
# COMPUTER SYSTEMS MANAGER                               122
# ADMINISTRATIVE STAFF ANALYST                           116
#                                                       ...
# COMMISSIONER OF COMMUNITY DEVELOPMENT                    1
# ASSIST COMMISSIONER FOR INTERGOVERNMENTAL RELATIONS      1
# DIRECTOR OF PUBLIC INFORMATION                           1
# SPECIAL ASSISTANT DISTRICT ATTORNEY                      1
# ADMINISTRATIIVE TAXI & LIMOUSINE INSPECTOR               1
# Name: Job, Length: 260, dtype: int64

# %% [markdown]
# # Label encoding

# %%
from sklearn import preprocessing

# %%
job_le = preprocessing.LabelEncoder()
loc_le = preprocessing.LabelEncoder()

# %%
Data['Job'] = job_le.fit_transform(Data['Job'])

# %%
Data['Work Location'] = loc_le.fit_transform(Data['Work Location'])

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age  Years of experience  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36                    1
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59                   26
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60                   26
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56                   22
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45                   21
#
#    Work Location  Job  Salary
# 0             11  347   55125
# 1              6   71  117748
# 2              6  110   93534
# 3              6  966   67600
# 4              6  419   81246

# %%
plt.boxplot(Data['Job'])
plt.show()

# %%
print('Median: ',Data['Job'].median())
# Out:
# Median:  957.0

# %%
plt.boxplot(Data['Work Location'])
plt.show()

# %%
print('Median: ',Data['Work Location'].median())
# Out:
# Median:  6.0

# %% [markdown]
# # Univariate analysis

# %%
import seaborn as sns

# %%
plt.subplots(figsize = (500,5))
sns.boxplot(x ='Job', y='Salary', data = Data)
# Out:
# <AxesSubplot:xlabel='Job', ylabel='Salary'>

# %%
sns.countplot(x = 'Work Location', data = Data)
# Out:
# <AxesSubplot:xlabel='Work Location', ylabel='count'>

# %%
print(loc_le.inverse_transform([6]),': ',sum(Data['Work Location']==6))
print(loc_le.inverse_transform([11]),': ',sum(Data['Work Location']==11))
print(loc_le.inverse_transform([2]),': ',sum(Data['Work Location']==2))
print(loc_le.inverse_transform([1]),': ',sum(Data['Work Location']==1))
# Out:
# ['MANHATTAN'] :  214945
# ['QUEENS'] :  46255
# ['BROOKLYN'] :  39878
# ['BRONX'] :  21456

# %%
Data['Work Location'].median()
# Out:
# 6.0

# %%
plt.subplots(figsize=(10,5))
sns.countplot(x = 'Years of experience', data = Data)
# Out:
# <AxesSubplot:xlabel='Years of experience', ylabel='count'>

# %%
print(sum(Data['Years of experience']==6))
print(sum(Data['Years of experience']==3))
print(sum(Data['Years of experience']==1))
print(sum(Data['Years of experience']==4))
print('')
print(sum(Data['Years of experience']==13))
# Out:
# 20407
# 20267
# 19345
# 18371
#
# 4644

# %%
Data['Years of experience'].median()
# Out:
# 10.0

# %%
plt.subplots(figsize=(500, 5))
sns.countplot(x = 'Job', data = Data)
# Out:
# <AxesSubplot:xlabel='Job', ylabel='count'>

# %%
print(sum(Data['Job']==131))
print(sum(Data['Job']==957))
print(sum(Data['Job']==1239))
print(sum(Data['Job']==1246))
# Out:
# 31382
# 23550
# 58576
# 28933

# %%
print(Data['Job'].median())
# Out:
# 957.0

# %%
plt.subplots(figsize = (10,5))
sns.countplot(x = 'Age', data = Data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# # Bivariate analysis

# %%
plt.subplots(figsize=(10,5))
sns.lineplot(x = Data['Years of experience'], y = Data['Salary'], data = Data)
# Out:
# <AxesSubplot:xlabel='Years of experience', ylabel='Salary'>

# %%
plt.subplots(figsize=(500,5))
sns.barplot(x = Data['Job'], y = Data['Salary'])
# Out:
# <AxesSubplot:xlabel='Job', ylabel='Salary'>

# %%
plt.subplots(figsize = (20, 5))
sns.lineplot(x = 'Job', y = 'Salary', data = Data)
# Out:
# <AxesSubplot:xlabel='Job', ylabel='Salary'>

# %%
job_le.inverse_transform([945])
# Out:
# array(['PENSION INVESTMENT ADVISOR'], dtype=object)

# %%
plt.subplots(figsize=(10,5))
sns.barplot(x = 'Job', y = 'Salary', data = Data[Data['Job']<20])
# Out:
# <AxesSubplot:xlabel='Job', ylabel='Salary'>

# %%
plt.subplots(figsize = (10,5))
sns.barplot(x = 'Years of experience', y = 'Salary', data = Data)
# Out:
# <AxesSubplot:xlabel='Years of experience', ylabel='Salary'>

# %%
print('No. of employees with 0 years of experience: ',(sum(Data['Years of experience']==0)))
print('No. of employees with 1 years of experience: ',(sum(Data['Years of experience']==1)))
print('No. of employees with 2 years of experience: ',(sum(Data['Years of experience']==2)))
print('No. of employees with 3 years of experience: ',(sum(Data['Years of experience']==3)))
# Out:
# No. of employees with 0 years of experience:  7683
# No. of employees with 1 years of experience:  19345
# No. of employees with 2 years of experience:  9871
# No. of employees with 3 years of experience:  20267

# %%
sns.barplot(x = 'Work Location', y = 'Salary', data = Data)
# Out:
# <AxesSubplot:xlabel='Work Location', ylabel='Salary'>

# %%
loc_le.inverse_transform([16, 9, 0])
# Out:
# array(['WASHINGTON DC', 'OTHER', 'ALBANY'], dtype=object)

# %% [markdown]
# # Multivariate analysis

# %%
Data.corr()
# Out:
#                           Age  Years of experience  Work Location       Job  \
# Age                  1.000000             0.876353       0.009884  0.064763
# Years of experience  0.876353             1.000000       0.011359  0.073711
# Work Location        0.009884             0.011359       1.000000 -0.036534
# Job                  0.064763             0.073711      -0.036534  1.000000
# Salary               0.350658             0.400111       0.053000  0.263192
#
#                        Salary
# Age                  0.350658
# Years of experience  0.400111
# Work Location        0.053000
# Job                  0.263192
# Salary               1.000000

# %%
sns.set(rc={'figure.figsize':(8,8)})
ax = sns.heatmap(Data.corr(), annot=True, linewidths=1, fmt='.2f')

# %%
sns.pairplot(Data)

# %%
Data.head()
# Out:
#                  Agency Name                Name  Age  Years of experience  \
# 0  ADMIN FOR CHILDREN'S SVCS  VARA PERRY SPENCER   36                    1
# 1  ADMIN FOR CHILDREN'S SVCS       STEVEN BIEBER   59                   26
# 2  ADMIN FOR CHILDREN'S SVCS        RICHARD BIER   60                   26
# 3  ADMIN FOR CHILDREN'S SVCS         DONNA BILAK   56                   22
# 4  ADMIN FOR CHILDREN'S SVCS         KAZI BILLAH   45                   21
#
#    Work Location  Job  Salary
# 0             11  347   55125
# 1              6   71  117748
# 2              6  110   93534
# 3              6  966   67600
# 4              6  419   81246

# %%
Data.drop(columns = ['Agency Name','Name'], inplace = True)

# %%
Data.head()
# Out:
#    Age  Years of experience  Work Location  Job  Salary
# 0   36                    1             11  347   55125
# 1   59                   26              6   71  117748
# 2   60                   26              6  110   93534
# 3   56                   22              6  966   67600
# 4   45                   21              6  419   81246

# %% [markdown]
# # Building learning models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
X = Data[['Age','Years of experience','Work Location','Job']]
y = Data[['Salary']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
lin = LinearRegression()
lin.fit(X_train, y_train)

lin_y_pred = lin.predict(X_test)

print('Mean Squared Error: ',mean_squared_error(y_test, lin_y_pred))
print('R2 score: ',r2_score(y_test, lin_y_pred))
# Out:
# Mean Squared Error:  810176123.3771845
# R2 score:  0.21663432826038032

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(random_state = 1)
gbr.fit(X_train, y_train.values.ravel())

gbr_y_pred = gbr.predict(X_test)

print('Mean Squared Error: ',mean_squared_error(y_test, gbr_y_pred))
print('R2 score: ',r2_score(y_test, gbr_y_pred))
# Out:
# Mean Squared Error:  345265745.1568478
# R2 score:  0.6661598329310983

# %%
from sklearn.model_selection import GridSearchCV

# %%
gbr = GradientBoostingRegressor(random_state = 1)

param_grid = {
    'n_estimators': [100],
    'learning_rate': [0.1, 0.01, 1],
    'max_depth': [3,5]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 133014240.7324647
# R squared error: 0.8713874834918924

# %%
param_grid = {
    'n_estimators': [100],
    'learning_rate': [2, 1.01, 1],
    'max_depth': [3,5,7]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 133014240.7324647
# R squared error: 0.8713874834918924

# %%
param_grid = {
    'n_estimators': [100],
    'learning_rate': [1.02, 1.1, 1],
    'max_depth': [3,5,7]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 133014240.7324647
# R squared error: 0.8713874834918924

# %%
param_grid = {
    'n_estimators': [100],
    'learning_rate': [1.02, 1.03, 1],
    'max_depth': [5,6,7]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 133014240.7324647
# R squared error: 0.8713874834918924

# %%
param_grid = {
    'n_estimators': [100],
    'learning_rate': [1.04, 1.05, 1],
    'max_depth': [3,4,5]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1.05, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 126137087.84673156
# R squared error: 0.8780370567569395

# %%
param_grid = {
    'n_estimators': [100],
    'learning_rate': [1.05, 1.06, 1.07],
    'max_depth': [3,4,5]
}

grid_search = GridSearchCV(gbr, param_grid, cv=4, scoring=['r2','neg_mean_squared_error'], refit = 'neg_mean_squared_error')
grid_search.fit(X_train, y_train.values.ravel())

best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

gbr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, gbr_y_pred))
print("R squared error:",r2_score(y_test, gbr_y_pred))
# Out:
# Best Hyperparameters: {'learning_rate': 1.05, 'max_depth': 5, 'n_estimators': 100}
# Validation MSE: 126137087.84673156
# R squared error: 0.8780370567569395

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state = 1)
rfr.fit(X_train, y_train.values.ravel())

rfr_y_pred = rfr.predict(X_test)

print('Mean Squared Error: ',mean_squared_error(y_test, rfr_y_pred))
print('R2 score: ',r2_score(y_test, rfr_y_pred))
# Out:
# Mean Squared Error:  135855066.0904361
# R2 score:  0.8686406670891014

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 5}
# Validation MSE: 545514381.5871389
# R squared error: 0.47253784992540226

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 5}
# Validation MSE: 545514381.5871389
# R squared error: 0.47253784992540226

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [7,10,20],
    'min_samples_split': [2]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 20}
# Validation MSE: 130558275.4792571
# R squared error: 0.8737621756296073

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [20,30,40],
    'min_samples_split': [2]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 20}
# Validation MSE: 130558275.4792571
# R squared error: 0.8737621756296073

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [19,20,21],
    'min_samples_split': [2]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 19}
# Validation MSE: 130868919.28612034
# R squared error: 0.873461811687233

# %%
param_dist = {
    'n_estimators': [100],
    'max_depth': [18,19,22],
    'min_samples_split': [2]
}

random_search = RandomizedSearchCV(rfr, param_dist, cv=4, scoring='neg_mean_squared_error')
random_search.fit(X_train, y_train.values.ravel())

best_model = random_search.best_estimator_
best_params = random_search.best_params_

rfr_y_pred = best_model.predict(X_test)

print("Best Hyperparameters:", best_params)
print("Validation MSE:", mean_squared_error(y_test, rfr_y_pred))
print("R squared error:",r2_score(y_test, rfr_y_pred))
# Out:
# C:\Users\praky\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 19}
# Validation MSE: 130868919.28612034
# R squared error: 0.873461811687233

# %% [markdown]
# # Best predictive model

# %%
Best_model = GradientBoostingRegressor(learning_rate = 1.05, max_depth = 5, n_estimators = 100, random_state = 1)
Best_model.fit(X_train, y_train.values.ravel())

y_pred_train = Best_model.predict(X_train)
y_pred_test = Best_model.predict(X_test)

print('Mean Squared Error value of train data: ',mean_squared_error(y_train, y_pred_train))
print('R2 score value of train data: ',r2_score(y_train, y_pred_train))
print('\n')
print('Mean Squared Error value of test data: ',mean_squared_error(y_test, y_pred_test))
print('R2 score value of test data: ',r2_score(y_test, y_pred_test))
# Out:
# Mean Squared Error value of train data:  109196064.61768118
# R2 score value of train data:  0.8950331495049493
#
#
# Mean Squared Error value of test data:  126137087.84673156
# R2 score value of test data:  0.8780370567569395
